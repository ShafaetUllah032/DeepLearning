# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
plt.figure(figsize=(10,7))
fig,axs=plt.subplots(3,2)
axs[0,0].set_facecolor('red')
fig.set_facecolor('green')

# %%
plt.figure(figsize=(10,7))
fig,axs=plt.subplots(3,2)
axs[0,0].set_facecolor('red')
axs[2,1].set_facecolor('green')

# %%
for i in range(1,4):
    ax=plt.subplot(121)
    ax1=plt.subplot(122)
    plt.show()
